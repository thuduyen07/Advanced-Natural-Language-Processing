# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Thu thập các đường dẫn từ URL

# %%
import requests
import os
from tqdm import tqdm
from bs4 import BeautifulSoup as bs
from urllib.parse import urljoin

import re

def find_links_with_document(url):
    response = requests.get(url)
    if response.status_code == 200:
        content = response
        pattern = r"(?=.*document).*\bhttp[s]?://\S+\b"
        links_with_document = []
        soup = bs(content, "lxml")
        links = soup.find_all("a")

        for link in links:
            href = link.get("href")
            if href:
                if re.search(pattern, href):
                    links_with_document.append(href)
                    print(href)

        return links_with_document
    else:
        print("Failed to retrieve the web page.")
        return []

# %% [markdown]
# # Download file HTML

# %%
def download_fileHTML(filename, url):
  response = requests.get(url)
  html_content = response.text
    # Đường dẫn đến thư mục bạn muốn lưu trữ file tải về
  folder_path = '/content/drive/MyDrive/XLNNTN-MSc-S2/file_html'

  # Kiểm tra xem thư mục đích có tồn tại không, nếu không thì tạo mới
  if not os.path.exists(folder_path):
    os.makedirs(folder_path)
  # Đường dẫn đến file đích
  file_path = os.path.join(folder_path, filename)

  # Lưu nội dung vào file HTML
  with open(file_path, "w", encoding='utf-8') as file:
      file.write(html_content)

  print("Tải xuống hoàn thành. Source code được lưu trong file "+filename)

# %% [markdown]
# # Download images
#
# Ref: https://www.thepythoncode.com/article/download-web-page-images-python

# %%
def is_valid(url):
    """
    Checks whether `url` is a valid URL.
    """
    parsed = urlparse(url)
    return bool(parsed.netloc) and bool(parsed.scheme)

def get_all_images(url):
    """
    Returns all image URLs on a single `url`
    """
    soup = bs(requests.get(url).content, "html.parser")
    #print("---soup---\n", soup)
    urls = []
    for img in tqdm(soup.find_all("img",attrs={'class':'absimg'}), "Extracting images"):
        img_url = img.attrs.get("src") or img.attrs.get("data-src") or img.attrs.get("data-original") or img.attrs.get("orig")
        print(img_url)
        if not img_url:
            # if img does not contain src attribute, just skip
            continue
        # make the URL absolute by joining domain with the URL that is just extracted
        img_url = urljoin(url, img_url)
        try:
            pos = img_url.index("?")
            img_url = img_url[:pos]
        except ValueError:
            pass
        # finally, if the url is valid
        if is_valid(img_url):
            urls.append(img_url)
    return urls

def download(url, pathname):
    """
    Downloads a file given an URL and puts it in the folder `pathname`
    """
    # if path doesn't exist, make that path dir
    if not os.path.isdir(pathname):
        os.makedirs(pathname)
    # download the body of response by chunk, not immediately
    response = requests.get(url, stream=True)
    # get the total file size
    file_size = int(response.headers.get("Content-Length", 0))
    # get the file name
    filename = os.path.join(pathname, url.split("/")[-1])
    # progress bar, changing the unit to bytes instead of iteration (default by tqdm)
    progress = tqdm(response.iter_content(1024), f"Downloading {filename}", total=file_size, unit="B", unit_scale=True, unit_divisor=1024)
    with open(filename, "wb") as f:
        for data in progress.iterable:
            # write data read to the file
            f.write(data)
            # update the progress bar manually
            progress.update(len(data))

# %% [markdown]
# # Download Text

# %% [markdown]
# ## Get Div's Style Attribute (Top, Left)

# %%
def GetStyle_Attribute(tags):

  # Kiểm tra xem thẻ div có thuộc tính style hay không
  if 'style' in tags.attrs:
      # Lấy giá trị của thuộc tính style
      style_value = tags['style']

      # Tách các cặp key-value trong thuộc tính style
      style_pairs = style_value.split(';')

      # Tìm giá trị của "top" và "left"
      top_value = None
      left_value = None

      for pair in style_pairs:
          key_value = pair.split(':', 1)
          if len(key_value) == 2:
              key = key_value[0].strip()
              value = key_value[1].strip()
              if key == 'top':
                  top_value = int(value.rstrip('px'))
              elif key == 'left':
                  left_value = int(value.rstrip('px'))
      return top_value, left_value
  else:
      return None, None

# %% [markdown]
# ## Read and write back to text file

# %%
import re
from requests.auth import HTTPBasicAuth
def get_all_text(source, filename):

    # Đường dẫn đến thư mục bạn muốn lưu trữ file tải về
    folder_path = '/content/drive/MyDrive/XLNNTN-MSc-S2/Text'

    # Kiểm tra xem thư mục đích có tồn tại không, nếu không thì tạo mới
    if not os.path.exists(folder_path):
      os.makedirs(folder_path)
    # Đường dẫn đến file đích
    file_path = os.path.join(folder_path, filename + '.txt')


    # Đọc nội dung từ file HTML
    path_htmlfile = source +'/'+ filename + '.html'
    with open(path_htmlfile, 'r') as file:
        html_content = file.read()
        print("đọc thành công")

    soup = bs(html_content, 'html.parser')
    content = soup.find('div', class_='outer_page_container')

    # Lọc các thẻ trên file HTML
    tags = content.find_all(['div', 'span'])

    # In ra nội dung của các thẻ
    # Start_top là mức trung bình giữa các kí tự trên cùng 1 hàng
    with open(file_path, 'w', encoding='utf-8') as file:
      top, left = GetStyle_Attribute(tags[0])
      start_top = top or 0

      for tag in tags:
        if tag.text and not re.match(r'^\n', tag.text):
          top, left = GetStyle_Attribute(tag)
          top = top or start_top

          if(len(tag.find_all(recursive=False)) > 0):
            if((top - start_top > 19 or (top - start_top) < -90) and tag.get_text() != " " and tag.get_text() != None ):
              file.write( "\n"+str(top)+";"+str(left)+";"+str(start_top)+";")
              start_top = top
            continue
          elif((top - start_top > 19 or (top - start_top) < -90) and tag.get_text() != " " and tag.get_text() != None ):
            file.write( "\n"+str(top)+";"+str(left)+";"+str(start_top)+";"+tag.get_text())
            start_top = top
          elif(top - start_top < 19 and tag.get_text() != " " and tag.get_text() != None ):
            #file.write( "\n"+"--- " +str(top)+ " --- "+str(start_top))
            file.write(tag.get_text())
            if(top > start_top):
              start_top =(start_top + top)/2

# %% [markdown]
# ## Check String

# %% [markdown]
# ### Check String is numberic, alphabet,... or not

# %%
def check_string(string):
    count = 0
    result = 1
    if(len(string) > 0):
      for char in string:

        # Kiểm tra số
        if re.search(r'\d', char):
            count = count + 1
            #print(str(count)+" "+ char)

        # Kiểm tra chữ cái
        if re.search(r'[a-zA-Z]', char):
            count = count + 1
            #print(str(count)+" "+ char)

        # Kiểm tra kí tự đặc biệt
        if re.search(r'\W', char):
            count = count + 1
            #print(str(count)+" "+ char)

      result = count/len(string)
    return result

# %% [markdown]
# ### Check the match between 2 strings

# %%
# !pip install python-Levenshtein
# Out:
# Collecting python-Levenshtein
#   Downloading python_Levenshtein-0.21.1-py3-none-any.whl (9.4 kB)
# Collecting Levenshtein==0.21.1 (from python-Levenshtein)
#   Downloading Levenshtein-0.21.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (172 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.5/172.5 kB 3.3 MB/s eta 0:00:00
# Collecting rapidfuzz<4.0.0,>=2.3.0 (from Levenshtein==0.21.1->python-Levenshtein)
#   Downloading rapidfuzz-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 63.2 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, Levenshtein, python-Levenshtein
# Successfully installed Levenshtein-0.21.1 python-Levenshtein-0.21.1 rapidfuzz-3.2.0

# %%
import Levenshtein

def calculate_similarity(string1, string2):
    distance = Levenshtein.distance(string1, string2)
    max_length = max(len(string1), len(string2), 1)
    similarity = (max_length - distance) / max_length * 100
    return similarity

string1 = " "
string2 = ""

similarity_percentage = calculate_similarity(string1, string2)
print(f"Similarity: {similarity_percentage}%")
# Out:
# Similarity: 0.0%

# %%
def compare_remaining(string_A, string_B):
    strA = string_A.lower().strip().replace(" ", "")
    strB = string_B.lower().strip().replace(" ", "")

    if len(strA) > len(strB):
      temp = strA
      strA = strB
      strB = temp
    length_A = len(strA)
    length_B = len(strB)
    match_ratio = 0.0
    for i in range(0,length_B - length_A + 1):
      extracted = strB[i:length_A + i]
      match_ratio_extracted = calculate_similarity(extracted, strA)
      if(match_ratio_extracted < match_ratio):
        break
      else:
        match_ratio = match_ratio_extracted
    return float(match_ratio)

# string = "九重按劍起當席"
# # Ví dụ sử dụng
# chuoi_A = hcmus_translate(string)
# chuoi_B = "cửu trùng án kiếm khởi đương tịch "

# compare_remaining(chuoi_A, chuoi_B)

# %% [markdown]
# ### Call HCMUS_Traslatetor API

# %%
import json
import time

def hcmus_translate(text):
    url = 'https://api.clc.hcmus.edu.vn/sentencepairs/90/1'
    response = requests.request('POST', url, data={'nom_text': text})
    time.sleep(0.1)

    try:
        result = json.loads(response.text)['sentences']
        result = result[0][0]['pair']['modern_text']
        return result
    except:
        #print(f'[ERR] "{text}": {response.text}')
        return 'Cannot translate this text.'

# %% [markdown]
# ### Call HVDic_Traslatetor API

# %%
def hvdic_translate(text):
  count_Nom_Character = 0
  output = ""
  meaning = []
  if(text is not None):
    url = 'https://hvdic.thivien.net/transcript-query.json.php'
    headers = { 'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8' }

    # Request phonetics for Hán Việt (lang=1) first, if the response result is not
    # Hán Việt (contains blank lists) => Request phonetics for Nôm (lang=3)
    for lang in [1, 3]:
        payload = f'mode=trans&lang={lang}&input={text}'
        response = requests.request('POST', url, headers=headers, data=payload.encode())
        time.sleep(0.1)
        try:
            result = json.loads(response.text)['result']
        except:
            print(f'[ERR] {text}: {response.text}')
            result = {}
    for phonetics_dict in result:
      if phonetics_dict['t'] == 3 and len(phonetics_dict['o']) >= 0:
        output += phonetics_dict['i']
        meaning.append(phonetics_dict['o'])
        count_Nom_Character += 1
  return output, meaning, count_Nom_Character

# %%
from concurrent.futures import ThreadPoolExecutor

def remove_unprintable_characters(input_string):
    printable_chars = [char for char in input_string if char.isprintable()]
    return ''.join(printable_chars)

def remove_duplicates_from_B(A, B):
    unique_chars_A = set(A)
    new_B = ''
    if B is not None:
      B = remove_unprintable_characters(B)
      new_B = [char for char in B if char not in unique_chars_A]
    return ''.join(new_B)

def parallel_remove_duplicates(A, B):
    with ThreadPoolExecutor() as executor:
        future_B = executor.submit(remove_duplicates_from_B, A, B)

    result_B = future_B.result()

    return result_B

# %%
def check_String_Match(string, Nom_String, Meaning):
  VN_String = parallel_remove_duplicates(Nom_String, string)
  VN_Character = VN_String.split(' ')
  count_VN_Character = len(VN_Character)-1
  count = 0
  String_Match = ''
  Rate = 0
  if(len(Nom_String)>0):
    for char in VN_Character:
      char =  char.lower().strip()
      for mean in Meaning:
        for m in mean:
          if(calculate_similarity(m,char) >= 70):
            count += 1
            String_Match += char + " "
            Meaning.remove(mean)
            break

    Rate = count/len(Nom_String)
  Label = None
  if(Rate >= 0.75):
    Label = 'Reliable'
  elif(Rate >= 0.60):
    Label ='Trustable'
  elif(Rate >= 0.50):
    Label = 'Needs_verification'
  else:
    Label = 'Unknown'
  return Label, String_Match, Rate

# %%
# string = remove_unprintable_characters("整篆庫来台 chễnh")

# Nom_String, Meaning, count_Nom_Character = hvdic_translate(string)
# Label, String_Match, rate = check_String_Match(string, Nom_String, Meaning)
# print(rate)
# print(count_Nom_Character)
# print(String_Match)
# print(Label)
# Out:
# 0.2
# 5
# chễnh
# Unknown

# %% [markdown]
# ## Generate Excel File

# %% [markdown]
# ### Decorate cells

# %%
def FillColor_Cell(cell, type):
  color_mapping = {
  'Reliable': 'CCFFCC',  # Xanh nhạt
  'Trustable': 'FFFFCC',  # Vàng nhạt
  'Needs_verification': 'FFCCCC',  # Đỏ nhat
  'Unknown': 'FF0000', # Đỏ đậm
  'Heading':'FFFF00'
  }
  cell.fill = PatternFill(start_color=color_mapping[type], end_color=color_mapping[type], fill_type="solid")

# %% [markdown]
# ### Format and Border table

# %%
from openpyxl.styles import Border, Side
from openpyxl.utils import get_column_letter

def FormatTable(sheet):
  for col in sheet.columns:
    max_length = 0
    column = col[0].column_letter
    for cell in col:
        try:
            if len(str(cell.value)) > max_length:
                max_length = len(cell.value)
        except:
            pass
    adjusted_width = (max_length + 2) * 1.2
    sheet.column_dimensions[column].width = adjusted_width

  # Định dạng viền cho ô
  border = Border(left=Side(style='thin'),
                  right=Side(style='thin'),
                  top=Side(style='thin'),
                  bottom=Side(style='thin'))

  for row in sheet.iter_rows():
    if any(cell.value is not None for cell in row):
      for cell in row:
          cell.border = border

# %% [markdown]
# ### Create Heading

# %%
def CreateHeading(sheet):
  sheet["A1"] = "Top"
  sheet["B1"] = "Left"
  sheet["C1"] = "Start_top"
  sheet["D1"] = "Text"
  sheet["E1"] = "Translated by Document"
  sheet["F1"] = "Translated by Dictionary"
  FillColor_Cell(sheet["A1"],'Heading')
  FillColor_Cell(sheet["B1"],'Heading')
  FillColor_Cell(sheet["C1"],'Heading')
  FillColor_Cell(sheet["D1"],'Heading')
  FillColor_Cell(sheet["E1"],'Heading')
  FillColor_Cell(sheet["F1"],'Heading')

# %% [markdown]
# ### Write in Excel file

# %%
def WriteExcelFile(sheet, filetext_path):
  # Mở file văn bản và đọc từng dòng
  with open(filetext_path, "r") as file:
    for line in file:
      # Tách các thuộc tính trong dòng bằng dấu ";"
      attributes = line.strip().split(";")

      # Ghi các thuộc tính vào các cell tương ứng trong cùng một hàng
      sheet.append(attributes)

# %% [markdown]
# ### Separate Nôm text and Vietnamese Text

# %%
check_string("ẠCH VÂN AM QUỐC NGỮ")
# Out:
# 0.7894736842105263

# %%
def SeparateNomText(sheet):
  #row = 1
  # Check string and call api to translate
  for row in range(2, len(sheet["C"])):
    string = sheet.cell(row=row, column=4).value
    # Translate
    Nom_String, Meaning, count_Nom_Character = hvdic_translate(string)
    Label, String_Match, Rate = check_String_Match(string, Nom_String, Meaning)
    VN_String = parallel_remove_duplicates(Nom_String, string)
    value_to_search = ""
    if(count_Nom_Character > 0 and Rate == 0):
      value_to_search = hcmus_translate(sheet.cell(row=row, column=4).value)
      #print(value_to_search)


    elif(count_Nom_Character > 0 and Rate > 0.1):
      sheet.cell(row=row, column=6).value = hcmus_translate(Nom_String)

      if(Label != 'None'):
        sheet.cell(row=row, column=5).value = String_Match + "---in---[Original] " + VN_String
      if(Label == 'Reliable'):
        FillColor_Cell(sheet.cell(row=row, column=5),'Reliable')
      elif(Label == 'Trustable'):
        FillColor_Cell(sheet.cell(row=row, column=5),'Trustable')
      elif(Label == 'Needs_verification'):
        FillColor_Cell(sheet.cell(row=row, column=5),'Needs_verification')
      elif(Label == 'Unknown'):
        FillColor_Cell(sheet.cell(row=row, column=5),'Unknown')
      sheet.cell(row=row, column=4).value = Nom_String

    elif(count_Nom_Character == 0):
      continue


    for row_j in range(2, len(sheet["C"])):
      if(value_to_search == ""):
        break
      if(sheet.cell(row=row_j, column=4).value is not None):
        match_rate = compare_remaining(value_to_search, str(sheet.cell(row=row_j, column=4).value))
        if match_rate >= 75.00:
          # Ghi giá trị tìm được vào cell D4
          if(sheet.cell(row=row, column=5).value is not None):
            sheet.cell(row=row, column=5).value += sheet.cell(row=row_j, column=4).value
          else:
            sheet.cell(row=row, column=5).value = sheet.cell(row=row_j, column=4).value
            FillColor_Cell(sheet.cell(row=row, column=5),'Reliable')
          sheet.delete_rows(row_j)
        elif match_rate >= 60.00:
          # Ghi giá trị tìm được vào cell D4
          if(sheet.cell(row=row, column=5).value is None):
            sheet.cell(row=row, column=5).value = sheet.cell(row=row_j, column=4).value
            FillColor_Cell(sheet.cell(row=row, column=5),'Trustable')
            sheet.delete_rows(row_j)
        elif match_rate >= 52.00:
          # Ghi giá trị tìm được vào cell D4
          if(sheet.cell(row=row, column=5).value is None):
            sheet.cell(row=row, column=5).value = sheet.cell(row=row_j, column=4).value
            FillColor_Cell(sheet.cell(row=row, column=5),'Needs_verification')
            sheet.delete_rows(row_j)
      sheet.cell(row=row, column=6).value = value_to_search

# %%
import openpyxl
from openpyxl.styles import PatternFill
from openpyxl import Workbook
def output_Excel(filename):
  folder_path = '/content/drive/MyDrive/XLNNTN-MSc-S2/Text'
  filetext_path = os.path.join(folder_path, filename + '.txt')
  file_path_excel = os.path.join(folder_path, filename + '.xlsx')
  workbook = openpyxl.Workbook()
  sheet = workbook.active

  # Create Heading
  CreateHeading(sheet)
  # Write Excel file from file text
  WriteExcelFile(sheet, filetext_path)
  # Separate Text
  SeparateNomText(sheet)

  # Format Table
  FormatTable(sheet)

  filename = file_path_excel
  workbook.save(filename)

# %%
# output_Excel("Bạch-Van-Am-Quốc-Ngữ-Nguyễn-Bỉnh-Khiem")

# %% [markdown]
# # Main

# %%
def main(url, path):
    links_with_document = find_links_with_document(url=url)
    print(links_with_document.count)
    if links_with_document:
        print("Các liên kết chứa từ 'document':")

        source_fileHTML = '/content/drive/MyDrive/XLNNTN-MSc-S2/Constant_HTLM_file'
        for link in links_with_document:
            filename = str(link).split('/')[-1]
            images = get_all_images(link)
            download_fileHTML(filename + '.html',link)
            get_all_text(source_fileHTML, filename)
            output_Excel(filename)
            for img in images:
              download(img, path)

    else:
        print("Không tìm thấy liên kết chứa từ 'document'.")

# %% [markdown]
# # Run

# %%
if __name__ == '__main__':
    main("https://www.scribd.com/lists/21643875/Th%C6%A1-V%C4%83n-Han-Nom","/content/drive/MyDrive/XLNNTN-MSc-S2/images")
# Out:
# https://www.scribd.com/document/354356904/Thập-Giới-Co-Hồn-Quốc-Ngữ-Văn-Le-Thanh-Tong
# https://www.scribd.com/document/351003106/Thien-Nam-Ngữ-Lục-Thơ-Nom
# https://www.scribd.com/document/354358928/Cung-Oan-Ngam-Khuc-Nguyễn-Gia-Thiều-Le-Văn-Đặng-Diễn-Nom
# https://www.scribd.com/document/354358921/Chinh-Phụ-Ngam-Diễn-Ca-Nguyễn-Văn-Xuan
# https://www.scribd.com/document/354359286/Chinh-Phụ-Ngam-Han-Việt
# https://www.scribd.com/document/351002527/Ma-Thanh-Tan-Truyện-Lý-Hồng-Phượng
# https://www.scribd.com/document/354356908/Bạch-Van-Am-Quốc-Ngữ-Nguyễn-Bỉnh-Khiem
# https://www.scribd.com/document/354356906/Bai-Tựa-Đại-Nam-Quốc-Ngữ
# https://www.scribd.com/document/354361314/Minh-Tam-Bửu-Giam-Diễn-Nom
# https://www.scribd.com/document/354361116/Nữ-Tử-Tu-Tri-Diễn-Nom
# https://www.scribd.com/document/354361115/Mộng-Lien-Đinh-Thi-Thảo-Nguyễn-Gia-Tuyển
# https://www.scribd.com/document/354359991/Giao-Tử-Phu-Mạc-Đĩnh-Chi
# https://www.scribd.com/document/354359995/Hồ-Xuan-Hương-Thi-Tập-Le-Văn-Đặng-Diễn-Nom
# https://www.scribd.com/document/354358926/Cac-Bai-Tuyệt-Cu-Trong-Quốc-Am-Thi-Tập-Nguyễn-Đinh-Hoa-Le-Văn-Đặng
# https://www.scribd.com/document/354358920/Ba-Huyện-Thanh-Quan-Lam-Trau-Diễn-Nom
# https://www.scribd.com/document/354358923/Bai-Hat-Đĩ-Diễn-Nom
# https://www.scribd.com/document/354359285/Đi-Chợ-Tinh-Tiền-Diễn-Nom
# https://www.scribd.com/document/354359289/Di-Chuc-Văn-Nguyễn-Khuyến
# https://www.scribd.com/document/352233420/1958-Giai-Nhan-Kỳ-Ngộ-Phan-Chau-Trinh
# https://www.scribd.com/document/365582497/1547-Truyền-Kỳ-Mạn-Lục-Nguyễn-Dữ
# https://www.scribd.com/document/365802429/1950-Cung-Oan-Ngam-Khuc-Dẫn-Giải-Va-Chu-Thich-Ton-Thất-Lương
# https://www.scribd.com/document/365802849/1952-Gia-Huấn-Ca-Nguyễn-Trai-Đinh-Gia-Thuyết-Chu-Thich
# https://www.scribd.com/document/350234561/1898-Quảng-Tập-Viem-Văn-Edmond-Nordemann
# https://www.scribd.com/document/368541567/Tổng-Tập-Văn-Học-Nom-Thơ-Nom-Han-Luật-Nguyễn-Ta-Nhi
# https://www.scribd.com/document/352647408/Le-Triều-Nguyễn-Tướng-Cong-Gia-Huấn-Ca-Maurice-Durand
# https://www.scribd.com/document/352647934/Cung-Oan-Thi-Maurice-Durand
# https://www.scribd.com/document/352647926/Thien-Nam-Toan-Quốc-Diễn-Am-Maurice-Durand
# https://www.scribd.com/document/352647937/Truyện-Vua-Le-Thai-Tổ-Maurice-Durand
# https://www.scribd.com/document/352647415/Đại-Nam-Quốc-Tuý-Maurice-Durand
# https://www.scribd.com/document/352648389/Thanh-Tổ-Kệ-Diễn-Quốc-Am-Maurice-Durand
# https://www.scribd.com/document/352649175/Văn-Tế-Tướng-Sĩ-Trận-Vong-Maurice-Durand
# https://www.scribd.com/document/352649182/Bạch-Van-Thi-Tập-Maurice-Durand
# https://www.scribd.com/document/352649184/Phương-Hoa-Tan-Truyện-Maurice-Durand
# https://www.scribd.com/document/329053271/1958-Thien-Nam-Ngữ-Lục-Tập-1-Nguyễn-Lương-Ngọc-Đinh-Gia-Khanh
# https://www.scribd.com/document/352647412/Phật-Thuyết-Đại-Thanh-Mạt-Kiếp-Chan-Kinh-Maurice-Durand
# <built-in method count of list object at 0x7e8c9ff1b040>
# Các liên kết chứa từ 'document':
# Extracting images: 0it [00:00, ?it/s]
# Tải xuống hoàn thành. Source code được lưu trong file Thập-Giới-Co-Hồn-Quốc-Ngữ-Văn-Le-Thanh-Tong.html
# đọc thành công
#
# T  n g / u 8 n t h i ê n " a /  n / o n g + a , š luận ) , › œ 7
# Í tuyệt chăng Î Ï Ð Ñ
# @ ' n h ^ h ể n h á o e Y
# Extracting images: 0it [00:00, ?it/s]
# Tải xuống hoàn thành. Source code được lưu trong file Thien-Nam-Ngữ-Lục-Thơ-Nom.html
# đọc thành công
# Extracting images: 0it [00:00, ?it/s]
# Tải xuống hoàn thành. Source code được lưu trong file Cung-Oan-Ngam-Khuc-Nguyễn-Gia-Thiều-Le-Văn-Đặng-Diễn-Nom.html
# đọc thành công
# oán khúc
# ôn như hầu soạn
# vô đoan nguyệt lảo oán hồng nhan tịch mịch không khuê bảo triện tàn
# sầu khiêu tàn chúc liên cô ảnh lãn đối lăng hoa lý bội hoàn
# hà bình ngu khê hậu sinh 
# Extracting images: 0it [00:00, ?it/s]
# Tải xuống hoàn thành. Source code được lưu trong file Chinh-Phụ-Ngam-Diễn-Ca-Nguyễn-Văn-Xuan.html
# đọc thành công
# thanh trì nhân mục đặng trần tiên sinh côn trứ
# văn giang trung phú đoạn phu nhân điểm diễn âm
# thần khê đồng phong thừa thư
# Extracting images: 0it [00:00, ?it/s]
# Tải xuống hoàn thành. Source code được lưu trong file Chinh-Phụ-Ngam-Han-Việt.html
# đọc thành công
# chinh phụ ngâm khúc
# đặng trần côn trứ
# thiên địa phong trần
# hồng nhan đa truân
# du du bỉ thương hề thuỳ tạo nhân
# cổ bề thanh động trường thành nguyệt
# 5 phong hoả ảnh chiếu cam tuyền vân
# cửu trùng án kiếm khởi đương tịch
# bán dạ phi hịch truyền tướng quân
# thanh bình tam bách niên thiên hạ
# tùng thử nhung y thuộc vũ thần
# 10 sứ tinh thiên môn thôi hiểu phát
# hành nhân trọng pháp khinh ly biệt
# cung tiễn hề tại yêu
# thê noa hề biệt khuyết
# liệp liệp tinh kỳ hề xuất tái sầu
# 15 huyên huyên tiêu cổ hề từ gia oán
# hữu oán hề phân huề
# hữu sầu hề khế khoát
# lương nhân nhị thập ngô môn hào
# đầu bút nghiên hề sự cung đao
# 20 trực bả liên thành hiến minh thánh
# nguyện tương xích kiếm trảm thiên kiêu
# trượng phu thiên lý chí mã cách
# thái sơn nhất trịch khinh hồng mao
# tiện từ khuê khổn tùng chinh chiến
# 25 tây phong minh tiên xuất vị kiều
# vị kiều đầu thanh thuỷ câu
# thanh thuỷ biên thanh thảo đồ
# tống quân xứ hề tâm du du
# quân đăng đồ hề thiếp hận bất như câu
# 30 quân lâm lưu hề thiếp hận bất như chu
# thanh thanh hữu lưu thuỷ
# bất tẩy thiếp tâm sầu
# thênh thênh hữu phương thảo
# bất vong thiếp tâm ưu
# 35 ngữ phục ngữ hề giúp quân thủ
# bộ nhất bộ hề khiên quân nhu
# thiếp tâm tuỳ quân tự minh nguyệt
# quân tâm vạn lý thiên sơn tiễn
# trịch ly bôi hề vũ long tuyền
# 40 hoành chinh giáo hề chỉ hổ huyệt
# vân tuỳ giới tử lạp lâu lan
# tiếu hướng man khê đàm mã viện
# quân xuyên trang phục hồng như hà
# quân kỵ kiêu mã bạch như tuyết
# 45 kiêu mã hề loan linh
# chinh cổ hề nhân hành
# tu du trung hề đối diện
# khoảnh khắc lý hề phân trình
# phần trình hề hà lương
# 50 bồi hồi hề lộ bàng
# lộ bàng nhất vọng hề bái ương ương
# tiền xa hề bắc tế liễu
# hậu cưỡi hề tây tràng dương
# cưỡi xe tướng ủng quân lâm tái
# 55 dương liễu na tri thiếp đoạn trường
# khứ khứ lạc mai thanh tiệm viễn
# hàng hàng chinh bái sắc hà mang
# vọng vân khứ hề lang biết thiếp
# vọng sơn quy hề thiếp tư lang
# 60 lang khứ trình hề mông vũ ngoại
# thiếp quy xứ hề tạc dạ phòng
# quy khứ lưỡng hồi cố
# vân thanh hề sơn thương
# lang cố thiếp hề hàm dương
# 65 thiếp cố lang hề tiêu tương
# tiêu tương yên trở hàm dương thụ
# hàm dương thụ cách tiêu tương giang
# tương cố bất tương kiến
# thênh thênh mạch thượng tang
# 70 mạch thượng tang mạch thượng tang
# thiếp ý quân tâm thuỳ đoản trường
# tự tòng biệt hậu phong sa lũng
# minh nguyệt tri quân hà xứ túc
# cổ lai chinh chiến trường
# 75 vạn lý vô nhân ốc
# phong ngao ngao hề đả đắc nhân nhan tiều
# thuỷ thâm thâm hề khiếp đắc mã đề súc
# thú phu chẩm cổ ngoạ long sa
# chiến sĩ bão yên miên hổ lục
# 80 kim triêu hán há bạch đăng thành
# minh nhật hồ khuy thanh hải khúc
# thanh hải khúc thanh sơn cao phục đê
# thanh sơn tiền thanh khê đoạn phục tục
# thanh sơn thượng tuyết mông đầu
# 85 thanh khê hạ thuỷ một phúc
# khả liên đa thiểu thiết y nhân
# tư quy đương thử sầu nhan xúc
# cẩm trướng quân vương tri dã vô
# gian nan thuỳ vị hoạ chinh phu
# 90 liệu tưởng lương nhân kinh lịch xứ
# tiêu quan giác hãn hải ngung
# sương thôn vũ điếm
# Extracting images: 100%|██████████| 3/3 [00:00<00:00, 10188.59it/s]
# https://html.scribdassets.com/u83rx27285wxt7l/images/1-9ada7370b9.jpg
# http://html.scribd.com/u83rx27285wxt7l/images/2-9de3d2a0df.jpg
# http://html.scribd.com/u83rx27285wxt7l/images/3-f81615bbf7.jpg
# Tải xuống hoàn thành. Source code được lưu trong file Ma-Thanh-Tan-Truyện-Lý-Hồng-Phượng.html
# đọc thành công
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/1-9ada7370b9.jpg: 100%|██████████| 75.8k/75.8k [00:00<00:00, 122kB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/2-9de3d2a0df.jpg: 100%|██████████| 205k/205k [00:00<00:00, 312kB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/3-f81615bbf7.jpg: 100%|██████████| 203k/203k [00:00<00:00, 347kB/s]
# Extracting images: 0it [00:00, ?it/s]
# Tải xuống hoàn thành. Source code được lưu trong file Bạch-Van-Am-Quốc-Ngữ-Nguyễn-Bỉnh-Khiem.html
# đọc thành công
# đại chánh lục niên mùi khoa tiến sĩ cập đệ đệ giáp đệ danh trình quốc công nguyễn bỉnh khiêm thi tập công đợi thiếu thời
# bản huyện tri huyện du hành kiến công xuất đối vân lục thất công bất như tử trình trạng nguyên đối viết nhị thiên thạch nhược
# công gặp trường danh vọng trứ cư quan trí sĩ tác bạch vân am thi tập  hứng thơ bách thủ dụng quốc âm trường đoản luật
# đại ạ i d ộ t n à o h a y t i ể u c ó đ à i .
# từng  V i n h n h ụ c b a p h e n h ẳ n đ ã t ừ n g
#  biên Đ ê m t h a n h l à m b ạ n s á c h h a i b ê n .
# ở nào  ao cũng nào  Ở ắ t n ê n
# thay ử a n ơ i x u ấ t x ử n i ệ m c h o h a y .
#   mãi mấy M ă n g t r ú c c ò n t ư ơ i b ế p m ớ i s ô i .
# quen ả n h c ũ đ i ề n v i ê n
# Extracting images: 0it [00:00, ?it/s]
# Tải xuống hoàn thành. Source code được lưu trong file Bai-Tựa-Đại-Nam-Quốc-Ngữ.html
# đọc thành công
# thành thái kỷ hợi niên mạnh thu tuyên
# hải chu tử nguyễn văn tan biên tập
# đại nam quốc ngữ
# tự tử viết nhân vị chu nam thiệu nam thí do chính diện tường nhi lập hựu viết đa thức điểu thú thảo mộc chi danh thánh môn chi học cầu
# cao viễn yếm ti cận dĩ thử nhi nhập đạo dã dư tích quan nhân cải thố kiến sứ phòng kiên cố kỳ hữu cá tri tứ ngũ vẻ tri
# sở dĩ cập quan y thư hữu vị nhân chi thủ giáp hoá vi hoàng tảng ngư vấn chi lương y hoàng tảng thị hà ngư giai tri khảo chi bản thảo
# chú hoàng tảng vi cá tri phù quốc nhất quốc dã nhi hữu 䠂 nhân tề ngữ huống ngã quốc dữ bắc quốc ngôn ngữ đồng phi nam dịch bắc âm
# vạn vật hà do nhi tường tưởng phu khoả trùng tam bách nhân vi chi trường thiên địa chi tính nhân vi quý quý kỳ tri thức dã kim tắc nhàn ám
# tử viết
# hữu bằng tự viễn phương lai
# nhân bất tri nhi bất uẩn
# T r o n g p h ầ n d ị c h n g h ĩ a
# chi châu
# yểu điệu thục nữ
# sâm si hạnh thái
# yểu điệu thục nữ
# cầu chi bất đắc
# phản trắc
# sâm si hạnh thái
# yểu điệu thục nữ
# sâm si hạnh thái
# yểu điệu thục nữ
# cư chi
# ngự chi
# tướng chi
# doanh chi
# thành chi
# chi tắc vị vi chi trường nhi khả quý chi gia kỳ gian hữu bàng quan bác lãm bất xuyết chi luận thuyết vị chi nặc sinh thư chủ
# nhân dụng thị trắc nhiên tứ tước chúng sấu bách thị phàm chúng hình danh hiệu kiến ngôn luận nhất nhất khảo hạch hoặc giản nhi vị
# bị hoặc chú nhi bất minh hợi thỉ phân vân diệc nan cây chính nãi tham khảo tiền ngôn tiềm thần mặc ký bác cầu tinh uẩn hoạch ly
# nhũng phiền tiên hậu sâm điều uỷ thâm mật thành ngũ thập loại nhan viết đại nam quốc ngữ hoặc vị ngã bang khoa hoạn gia vô thử
# diệc vô sở tổn hà bất tòng chính giáo lập ngôn khước ư nhật dụng thường hành thượng luận tương hề dĩ vi phù thiên địa chi tinh anh
# ngụ ở vật nhất vật hữu nhất vật chi cả thảng thảng hoặc hoặc khoản khải quả văn hà dĩ cứu phu vật lý mao đầu thiên cẩu sam
# thương hà tinh thanh nữ huyền minh đằng lục hà thần hương đạo bạch đạo
# t ừ n g t h ứ m ộ t h o ặ c n g ư ờ i c h é p g i ả n l ư ợ c c h ư a đ ủ
# ( t h ỉ ) h a y phân ( p h â n )
# Extracting images: 0it [00:00, ?it/s]
# Tải xuống hoàn thành. Source code được lưu trong file Minh-Tam-Bửu-Giam-Diễn-Nom.html
# đọc thành công
# 《 minh tâm bảo giám 》
# [ minh ] phạm 立 bản tập
# mục 錄
# nhị
# thập thiên
# 《 minh tâm bảo giám 》 tự
# phu vi nhân tại thế sinh cư trung quốc bẩm tam tài chi đức vì vạn vật chi
# thánh hiền
# thuỳ giáo nhi tòng giáo giả đạt đạo vi tiên phi bác học vô dĩ quảng tri 不
# hy tích
# hạ vũ vương văn thiện ngôn do nhiên hạ bái hà huống phàm thế nhân hồ
# 1 hoàng vương
# “ cao dịch bản ” ] tác “ hoàng thượng ” .
# vi thiện
# phẩm biết
# 行 thậm
# đa sở dĩ kim nhân lãm quan tập 行 giả thiếu huống kim học giả 不 quá học
# kỳ văn nghệ vì tiên vị hữu tiên học đức 行 vì bản cập kim khuyên thế đa
# tích hiền
# văn đẳng thư diệc nãi ở thế 流 truyền
# kim chi hảo thánh thiện ngôn quân tử quan dĩ vi kỳ võng tri cổ kim chi yếu
# thường 行
# 行 phu
# suy tựa
# 念 trung
# bằng phi hoành
# vô nghi
# sở vi yên tòng sai ngộ hĩ
# hồng vũ nhị thập 六 年 tuế thứ quý dậu nhị nguyệt ký vọng vũ 林
# hậu học phạm 立 bổn tự
# trùng san 《 minh tâm bảo giám 》 tự
# viết minh
# minh tâm
# thông thị
# nhi 理
# nhân chi
# tẩy trạc chi tâm dĩ khứ 惡 như mộc dục kỳ thân dĩ khứ cấu cố minh kỳ
# chi uẩn
# áo kỳ nghĩa duy tại minh thiện 復 xưa cùng 理 tận tính nhi hữu nhật tân chi
# 益 kỳ minh tâm đắc 不 nhân thử nhi minh yên dư bình sinh trân ái thị thư
# ư thị ngự chi hạ triêu tịch phi lãm kỳ sở hỉ giả tự 句 立 ý đa
# dĩ trung hiếu vi tiên đến kỳ trung văn tự đa suyễn toại bá chính 拾 di quên
# hãy kỳ
# ở thế giáo vị tất vô tiểu bỏ vân
# thủ am tào huyền tự
# 6 thường
# sơ bản ,
# 1393 年
# S a I G linh N
# Extracting images: 0it [00:00, ?it/s]
# Tải xuống hoàn thành. Source code được lưu trong file Nữ-Tử-Tu-Tri-Diễn-Nom.html
# đọc thành công
# khải định tân dậu hạ
# nữ tử tu tri
# [ hà nội ] phúc an tàng bản
# Extracting images: 0it [00:00, ?it/s]
# Tải xuống hoàn thành. Source code được lưu trong file Mộng-Lien-Đinh-Thi-Thảo-Nguyễn-Gia-Tuyển.html
# đọc thành công
# duy tân canh tuất niên trọng xuân nguyệt liên  gia tuyển soạn
# nam thi tân quốc phong quyển 亗
# vân  chủ nhân phụng biên khê đình tuần phủ bình
# ( 1 a - 7 a )
# thừa thiên
# sơn tây
# Extracting images: 100%|██████████| 35/35 [00:00<00:00, 14510.29it/s]
# https://html.scribdassets.com/n28hh1cqo5z0gh7/images/1-31837694ee.jpg
# https://html.scribdassets.com/n28hh1cqo5z0gh7/images/1-31837694ee.jpg
# https://html.scribdassets.com/n28hh1cqo5z0gh7/images/1-31837694ee.jpg
# https://html.scribdassets.com/n28hh1cqo5z0gh7/images/1-31837694ee.jpg
# https://html.scribdassets.com/n28hh1cqo5z0gh7/images/1-31837694ee.jpg
# https://html.scribdassets.com/n28hh1cqo5z0gh7/images/1-31837694ee.jpg
# https://html.scribdassets.com/n28hh1cqo5z0gh7/images/1-31837694ee.jpg
# https://html.scribdassets.com/n28hh1cqo5z0gh7/images/1-31837694ee.jpg
# https://html.scribdassets.com/n28hh1cqo5z0gh7/images/1-31837694ee.jpg
# https://html.scribdassets.com/n28hh1cqo5z0gh7/images/1-31837694ee.jpg
# http://html.scribd.com/n28hh1cqo5z0gh7/images/2-f02a0ce456.jpg
# http://html.scribd.com/n28hh1cqo5z0gh7/images/2-f02a0ce456.jpg
# http://html.scribd.com/n28hh1cqo5z0gh7/images/2-f02a0ce456.jpg
# http://html.scribd.com/n28hh1cqo5z0gh7/images/2-f02a0ce456.jpg
# http://html.scribd.com/n28hh1cqo5z0gh7/images/2-f02a0ce456.jpg
# http://html.scribd.com/n28hh1cqo5z0gh7/images/2-f02a0ce456.jpg
# http://html.scribd.com/n28hh1cqo5z0gh7/images/2-f02a0ce456.jpg
# http://html.scribd.com/n28hh1cqo5z0gh7/images/2-f02a0ce456.jpg
# http://html.scribd.com/n28hh1cqo5z0gh7/images/2-f02a0ce456.jpg
# http://html.scribd.com/n28hh1cqo5z0gh7/images/2-f02a0ce456.jpg
# http://html.scribd.com/n28hh1cqo5z0gh7/images/2-f02a0ce456.jpg
# http://html.scribd.com/n28hh1cqo5z0gh7/images/2-f02a0ce456.jpg
# http://html.scribd.com/n28hh1cqo5z0gh7/images/2-f02a0ce456.jpg
# http://html.scribd.com/n28hh1cqo5z0gh7/images/3-c9053c9a55.jpg
# http://html.scribd.com/n28hh1cqo5z0gh7/images/3-c9053c9a55.jpg
# http://html.scribd.com/n28hh1cqo5z0gh7/images/3-c9053c9a55.jpg
# http://html.scribd.com/n28hh1cqo5z0gh7/images/3-c9053c9a55.jpg
# http://html.scribd.com/n28hh1cqo5z0gh7/images/3-c9053c9a55.jpg
# http://html.scribd.com/n28hh1cqo5z0gh7/images/3-c9053c9a55.jpg
# http://html.scribd.com/n28hh1cqo5z0gh7/images/3-c9053c9a55.jpg
# http://html.scribd.com/n28hh1cqo5z0gh7/images/3-c9053c9a55.jpg
# http://html.scribd.com/n28hh1cqo5z0gh7/images/3-c9053c9a55.jpg
# http://html.scribd.com/n28hh1cqo5z0gh7/images/3-c9053c9a55.jpg
# http://html.scribd.com/n28hh1cqo5z0gh7/images/3-c9053c9a55.jpg
# http://html.scribd.com/n28hh1cqo5z0gh7/images/3-c9053c9a55.jpg
# Tải xuống hoàn thành. Source code được lưu trong file Giao-Tử-Phu-Mạc-Đĩnh-Chi.html
# đọc thành công
# giáo phú
# mạc đĩnh trạng nguyên tử nhập minh ty thất nhật kiến chư địa ngục tái đắc hoàn sinh giáo tử phú
# nhất thiết thăng trầm
# mình sinh ngũ 
# nghiệp  
# sinh  ngũ trọc
# vì xem vi dạ
#  khó  
# tranh hơn tranh thiệt
# chơi bời tửu sắc
# khoe ăn khoe mặc
#  một chút
# vô thường thôi tốc
#  kêu  khóc
# [ xảy x ỉ ẻ ] [ đ ố i t r ó i ]
# xem thương bực tức
# đạp   ta N ấ u n ư ớ n g n g ư ờ i t a ,
# hồn xiêu phách lạc
# tội nhân giác lạc
# thiết lư thiết mã
# đã  ngắt ngắt
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/1-31837694ee.jpg: 100%|██████████| 22.5k/22.5k [00:00<00:00, 37.4kB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/1-31837694ee.jpg: 100%|██████████| 22.5k/22.5k [00:00<00:00, 4.08MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/1-31837694ee.jpg: 100%|██████████| 22.5k/22.5k [00:00<00:00, 4.56MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/1-31837694ee.jpg: 100%|██████████| 22.5k/22.5k [00:00<00:00, 2.58MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/1-31837694ee.jpg: 100%|██████████| 22.5k/22.5k [00:00<00:00, 3.45MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/1-31837694ee.jpg: 100%|██████████| 22.5k/22.5k [00:00<00:00, 3.56MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/1-31837694ee.jpg: 100%|██████████| 22.5k/22.5k [00:00<00:00, 3.50MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/1-31837694ee.jpg: 100%|██████████| 22.5k/22.5k [00:00<00:00, 3.59MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/1-31837694ee.jpg: 100%|██████████| 22.5k/22.5k [00:00<00:00, 3.44MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/1-31837694ee.jpg: 100%|██████████| 22.5k/22.5k [00:00<00:00, 4.12MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/2-f02a0ce456.jpg: 100%|██████████| 61.0k/61.0k [00:00<00:00, 103kB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/2-f02a0ce456.jpg: 100%|██████████| 61.0k/61.0k [00:00<00:00, 8.13MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/2-f02a0ce456.jpg: 100%|██████████| 61.0k/61.0k [00:00<00:00, 10.8MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/2-f02a0ce456.jpg: 100%|██████████| 61.0k/61.0k [00:00<00:00, 6.71MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/2-f02a0ce456.jpg: 100%|██████████| 61.0k/61.0k [00:00<00:00, 2.53MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/2-f02a0ce456.jpg: 100%|██████████| 61.0k/61.0k [00:00<00:00, 6.73MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/2-f02a0ce456.jpg: 100%|██████████| 61.0k/61.0k [00:00<00:00, 7.02MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/2-f02a0ce456.jpg: 100%|██████████| 61.0k/61.0k [00:00<00:00, 6.82MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/2-f02a0ce456.jpg: 100%|██████████| 61.0k/61.0k [00:00<00:00, 10.8MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/2-f02a0ce456.jpg: 100%|██████████| 61.0k/61.0k [00:00<00:00, 8.74MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/2-f02a0ce456.jpg: 100%|██████████| 61.0k/61.0k [00:00<00:00, 9.49MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/2-f02a0ce456.jpg: 100%|██████████| 61.0k/61.0k [00:00<00:00, 10.2MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/2-f02a0ce456.jpg: 100%|██████████| 61.0k/61.0k [00:00<00:00, 8.78MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/3-c9053c9a55.jpg: 100%|██████████| 62.2k/62.2k [00:00<00:00, 98.1kB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/3-c9053c9a55.jpg: 100%|██████████| 62.2k/62.2k [00:00<00:00, 7.34MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/3-c9053c9a55.jpg: 100%|██████████| 62.2k/62.2k [00:00<00:00, 7.22MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/3-c9053c9a55.jpg: 100%|██████████| 62.2k/62.2k [00:00<00:00, 9.71MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/3-c9053c9a55.jpg: 100%|██████████| 62.2k/62.2k [00:00<00:00, 10.7MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/3-c9053c9a55.jpg: 100%|██████████| 62.2k/62.2k [00:00<00:00, 7.75MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/3-c9053c9a55.jpg: 100%|██████████| 62.2k/62.2k [00:00<00:00, 7.09MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/3-c9053c9a55.jpg: 100%|██████████| 62.2k/62.2k [00:00<00:00, 6.16MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/3-c9053c9a55.jpg: 100%|██████████| 62.2k/62.2k [00:00<00:00, 9.52MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/3-c9053c9a55.jpg: 100%|██████████| 62.2k/62.2k [00:00<00:00, 6.31MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/3-c9053c9a55.jpg: 100%|██████████| 62.2k/62.2k [00:00<00:00, 2.80MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/3-c9053c9a55.jpg: 100%|██████████| 62.2k/62.2k [00:00<00:00, 10.2MB/s]
# Extracting images: 0it [00:00, ?it/s]
# Tải xuống hoàn thành. Source code được lưu trong file Hồ-Xuan-Hương-Thi-Tập-Le-Văn-Đặng-Diễn-Nom.html
# đọc thành công
# ngán nỗi ôm còn những tấp tênh
# thấp thoáng đầu muôn lún phún mưa T h â m t h
#     thử   b u ổ i s ớ m g i ó t u ô n
# Extracting images: 0it [00:00, ?it/s]
# Tải xuống hoàn thành. Source code được lưu trong file Cac-Bai-Tuyệt-Cu-Trong-Quốc-Am-Thi-Tập-Nguyễn-Đinh-Hoa-Le-Văn-Đặng.html
# đọc thành công
# xem  tơ  R à y l i ễ u đ ã r ủ t ơ m ề m .
#  phen liễu rủ  phen מ  M ộ t p h e n l i ễ u r ủ m ộ t p h e n m ề m .
# xuân t h ì t h u b a t h á n g ,
# cả  lã ách ả l ò n g m ư ợ n đ ắ p l ấ y h ơ i c ù n g .
# Extracting images: 0it [00:00, ?it/s]
# Tải xuống hoàn thành. Source code được lưu trong file Ba-Huyện-Thanh-Quan-Lam-Trau-Diễn-Nom.html
# đọc thành công
# thì chẳng được đâu ừ thì ông cống   thời 
# cho con ả thị đào
#  rằng xuân tái lai
# L i n e 4 : b ả n N ô m c h é p s a i c h ữ vệ ( v ệ ‘ t o p r o t e c t ’
# phó ả thị đào xuân bất tái lai
# mặt
# nước
# ai
# rằng
# khóm
# cho
# mai
# đợi
# lạnh ( l ã n h )
# nữ ( n ữ )
# [ thuỷ S I G N I F I ách + diện S I G N I F I ách ] d u p p l i c a t i n g dợn ( m i ệ n ‘ d r u n k ’ )
# đi  mặt nước /  đợi ai
# cho về kiếm chăng / kẻo mai  chăng
# Extracting images: 0it [00:00, ?it/s]
# Tải xuống hoàn thành. Source code được lưu trong file Bai-Hat-Đĩ-Diễn-Nom.html
# đọc thành công
# Extracting images: 0it [00:00, ?it/s]
# Tải xuống hoàn thành. Source code được lưu trong file Đi-Chợ-Tinh-Tiền-Diễn-Nom.html
# đọc thành công
#  tiền
# đoái tiên   tiền 
# tiền    với  đồng 
# 5
# có gì mà tính chẳng thông
# tiền   tay xem đồng chè tươi
#   đồng  chàng đi
# 10
# chăng chăng   kẻo chàng hồ nghi
# chăng   đồng   
#  đồng nải chuối chẵn thì một quan
# Extracting images: 0it [00:00, ?it/s]
# Tải xuống hoàn thành. Source code được lưu trong file Di-Chuc-Văn-Nguyễn-Khuyến.html
# đọc thành công
# di
# ngã niên trị bát bát
# ngã  phùng cửu cửu
# ta tai ngã  lương
# thọ kỷ mại tiên khảo
# ta tai ngã học thiển
# khôi nhiên chiêm long thủ
# khởi phi tiên khảo 
# lưu dĩ tích ngã phụ
# khởi phi tiên khảo danh
# bất tố dĩ lưu hậu
# bình nhật chăng thốn công
# phủ ngưỡng dĩ tàm phụ
# túc hĩ diệc hà cầu
# tử  vật yêm cửu
# tử hạnh đắc toàn quy
#  hạnh đắc thân phụ
# quan khâm bất khả mỹ
# chỉ dĩ liễm túc thủ
# cụ soạn bất khả phong
# chỉ dĩ đáp bôn tẩu
# bất khả tả chúc văn
# bất khả vi đối cú
# bất khả thiết minh tinh
# bất khả đề thần chủ
# bất khả đạt môn sinh
# bất khả phó liêu hữu
# tân khách bất khả chiêu
# phụ điếu bất khả thụ
# thử giai luỵ ư sinh
# tử giả diệc hề hữu
# chăng dĩ trọng ngô quá
# hiêu nhiên chúng đa khẩu
# duy ở  chi nhật
# kỳ thiên đạo tiền cữu
# vu công bát cửu nhân
# xuy tống liệt tả hữu
# thảo thảo tử  hoàn
# lỗi ngã dĩ bôi tửu
# sở đắc tân sắc bằng
# phong hoàn nạp sứ phủ
# viên đề mộ thạch bi
# hoàng nguyễn cố hưu tẩu
# trị
# bát bát
#  phùng
# cửu cửu
# k i n h d ị c h l ấ y s ố cửu ( c ử u ) đ ặ t t ê n h à o d ư ơ n g
# ta tai
#  lương
# thọ kỷ
# mời
# tiên khảo
# học thiển
# khôi nhiên
# chiêm long thủ
# khởi phi tiên khảo 
# khởi
# lưu dĩ tích
# lưu dĩ tích ngã phụ
# bất tố dĩ lưu hậu
# bình nhật
# chăng thốn công
# phủ ngưỡng dĩ tàm phụ
# dĩ d ĩ = t h ô i
# Extracting images: 0it [00:00, ?it/s]
# Tải xuống hoàn thành. Source code được lưu trong file 1958-Giai-Nhan-Kỳ-Ngộ-Phan-Chau-Trinh.html
# đọc thành công
# Extracting images: 0it [00:00, ?it/s]
# Tải xuống hoàn thành. Source code được lưu trong file 1547-Truyền-Kỳ-Mạn-Lục-Nguyễn-Dữ.html
# đọc thành công
# Extracting images: 0it [00:00, ?it/s]
# Tải xuống hoàn thành. Source code được lưu trong file 1950-Cung-Oan-Ngam-Khuc-Dẫn-Giải-Va-Chu-Thich-Ton-Thất-Lương.html
# đọc thành công
# Extracting images: 0it [00:00, ?it/s]
# Tải xuống hoàn thành. Source code được lưu trong file 1952-Gia-Huấn-Ca-Nguyễn-Trai-Đinh-Gia-Thuyết-Chu-Thich.html
# đọc thành công
# Extracting images: 0it [00:00, ?it/s]
# Tải xuống hoàn thành. Source code được lưu trong file 1898-Quảng-Tập-Viem-Văn-Edmond-Nordemann.html
# đọc thành công
# Extracting images: 100%|██████████| 3/3 [00:00<00:00, 10442.25it/s]
# https://html.scribdassets.com/2tjr2z8aps67uaev/images/1-7b36f001fc.jpg
# http://html.scribd.com/2tjr2z8aps67uaev/images/2-c97f8ad59a.jpg
# http://html.scribd.com/2tjr2z8aps67uaev/images/3-175373fe62.jpg
# Tải xuống hoàn thành. Source code được lưu trong file Tổng-Tập-Văn-Học-Nom-Thơ-Nom-Han-Luật-Nguyễn-Ta-Nhi.html
# đọc thành công
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/1-7b36f001fc.jpg: 100%|██████████| 41.5k/41.5k [00:00<00:00, 1.91MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/2-c97f8ad59a.jpg: 100%|██████████| 12.8k/12.8k [00:00<00:00, 2.07MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/3-175373fe62.jpg: 100%|██████████| 329k/329k [00:00<00:00, 23.1MB/s]
# Extracting images: 0it [00:00, ?it/s]
# Tải xuống hoàn thành. Source code được lưu trong file Le-Triều-Nguyễn-Tướng-Cong-Gia-Huấn-Ca-Maurice-Durand.html
# đọc thành công
# Extracting images: 0it [00:00, ?it/s]
# Tải xuống hoàn thành. Source code được lưu trong file Cung-Oan-Thi-Maurice-Durand.html
# đọc thành công
# Extracting images: 0it [00:00, ?it/s]
# Tải xuống hoàn thành. Source code được lưu trong file Thien-Nam-Toan-Quốc-Diễn-Am-Maurice-Durand.html
# đọc thành công
# Extracting images: 0it [00:00, ?it/s]
# Tải xuống hoàn thành. Source code được lưu trong file Truyện-Vua-Le-Thai-Tổ-Maurice-Durand.html
# đọc thành công
# Extracting images: 100%|██████████| 3/3 [00:00<00:00, 10529.63it/s]
# https://html.scribdassets.com/997igm3ruo5xyeea/images/1-47603f3b2e.jpg
# http://html.scribd.com/997igm3ruo5xyeea/images/2-daccb94428.jpg
# http://html.scribd.com/997igm3ruo5xyeea/images/3-73e23d7588.jpg
# Tải xuống hoàn thành. Source code được lưu trong file Đại-Nam-Quốc-Tuý-Maurice-Durand.html
# đọc thành công
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/1-47603f3b2e.jpg: 100%|██████████| 81.0k/81.0k [00:00<00:00, 133kB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/2-daccb94428.jpg: 100%|██████████| 338k/338k [00:00<00:00, 525kB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/3-73e23d7588.jpg: 100%|██████████| 208k/208k [00:00<00:00, 248kB/s]
# Extracting images: 0it [00:00, ?it/s]
# Tải xuống hoàn thành. Source code được lưu trong file Thanh-Tổ-Kệ-Diễn-Quốc-Am-Maurice-Durand.html
# đọc thành công
# Extracting images: 0it [00:00, ?it/s]
# Tải xuống hoàn thành. Source code được lưu trong file Văn-Tế-Tướng-Sĩ-Trận-Vong-Maurice-Durand.html
# đọc thành công
# Extracting images: 100%|██████████| 3/3 [00:00<00:00, 1275.25it/s]
# https://html.scribdassets.com/1zzyzd1n5s5xyfta/images/1-2c7667b8f1.jpg
# http://html.scribd.com/1zzyzd1n5s5xyfta/images/2-64596c342c.jpg
# http://html.scribd.com/1zzyzd1n5s5xyfta/images/3-86cae9b550.jpg
# Tải xuống hoàn thành. Source code được lưu trong file Bạch-Van-Thi-Tập-Maurice-Durand.html
# đọc thành công
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/1-2c7667b8f1.jpg: 100%|██████████| 28.6k/28.6k [00:00<00:00, 3.17MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/2-64596c342c.jpg: 100%|██████████| 227k/227k [00:00<00:00, 12.0MB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/3-86cae9b550.jpg: 100%|██████████| 155k/155k [00:00<00:00, 13.1MB/s]
# Extracting images: 0it [00:00, ?it/s]
# Tải xuống hoàn thành. Source code được lưu trong file Phương-Hoa-Tan-Truyện-Maurice-Durand.html
# đọc thành công
# Extracting images: 100%|██████████| 3/3 [00:00<00:00, 10026.22it/s]
# https://html.scribdassets.com/2grobfym685jdrsl/images/1-118a9141d2.jpg
# http://html.scribd.com/2grobfym685jdrsl/images/2-ff987cf688.jpg
# http://html.scribd.com/2grobfym685jdrsl/images/3-a89f8e86e1.jpg
# Tải xuống hoàn thành. Source code được lưu trong file 1958-Thien-Nam-Ngữ-Lục-Tập-1-Nguyễn-Lương-Ngọc-Đinh-Gia-Khanh.html
# đọc thành công
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/1-118a9141d2.jpg: 100%|██████████| 67.6k/67.6k [00:00<00:00, 108kB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/2-ff987cf688.jpg: 100%|██████████| 81.3k/81.3k [00:00<00:00, 140kB/s]
# Downloading /content/drive/MyDrive/XLNNTN-MSc-S2/images/3-a89f8e86e1.jpg: 100%|██████████| 211k/211k [00:00<00:00, 307kB/s]
# Extracting images: 0it [00:00, ?it/s]
# Tải xuống hoàn thành. Source code được lưu trong file Phật-Thuyết-Đại-Thanh-Mạt-Kiếp-Chan-Kinh-Maurice-Durand.html
# đọc thành công
